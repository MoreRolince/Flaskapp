# %% [markdown]
# <a href="https://colab.research.google.com/github/MoreRolince/Flaskapp/blob/master/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score, normalized_mutual_info_score

# %%
df_train = pd.read_csv('/content/train.csv')
df_test = pd.read_csv('/content/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# Vérification des valeurs manquantes
print(df_train.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Vérification des valeurs manquantes
print(df_test.isnull().sum())
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Remplissage des valeurs manquantes pour 'Age' avec la médiane
imputer = SimpleImputer(strategy='median')
df_test['Age'] = imputer.fit_transform(df_test[['Age']])

# %%
# Remplissage des valeurs manquantes pour 'Age' avec la médiane
imputer = SimpleImputer(strategy='median')
df_train['Age'] = imputer.fit_transform(df_train[['Age']])

# %%
# Remplissage des valeurs manquantes pour 'Embarked' avec le mode
df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)
# Out:
# <ipython-input-25-99070efc1bff>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)

# %%
# Suppression de la colonne 'Cabin' trop incomplète
df_test.drop(columns=['Cabin'], inplace=True)

# Suppression de la colonne 'Cabin' trop incomplète
df_train.drop(columns=['Cabin'], inplace=True)

# %%
# Encodage des variables catégorielles1
le = LabelEncoder()
df_train['Sex'] = le.fit_transform(df_train['Sex'])
df_train['Embarked'] = le.fit_transform(df_train['Embarked'])

# Encodage des variables catégorielles2
le = LabelEncoder()
df_test['Sex'] = le.fit_transform(df_test['Sex'])
df_test['Embarked'] = le.fit_transform(df_test['Embarked'])

# %%
# Encodage des variables catégorielles1
le = LabelEncoder()
df_train['Sex'] = le.fit_transform(df_train['Sex'])
df_train['Embarked'] = le.fit_transform(df_train['Embarked'])


# Encodage des variables catégorielles1
le = LabelEncoder()
df_test['Sex'] = le.fit_transform(df_test['Sex'])
df_test['Embarked'] = le.fit_transform(df_test['Embarked'])

# %%
# Mise à l'échelle des données
scaler = StandardScaler()
# Select only numerical features for scaling
numerical_features = df_train.select_dtypes(include=np.number).columns[1:]  # Exclude 'PassengerId' and select numerical features
df_train[numerical_features] = scaler.fit_transform(df_train[numerical_features])

# %%
# Mise à l'échelle des données
scaler = StandardScaler()
# Select only numerical features for scaling
numerical_features = df_test.select_dtypes(include=np.number).columns[1:]  # Exclude 'PassengerId' and select numerical features
df_test[numerical_features] = scaler.fit_transform(df_test[numerical_features])

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.show()
# Out:
# Accuracy: 0.8212290502793296
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       105
#            1       0.81      0.74      0.77        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179

# %%
# Modèle supervisé - Random Forest
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(X_train)

# %%
a_ri = adjusted_rand_score(y_train, kmeans_labels)
n_mi = normalized_mutual_info_score(y_train, kmeans_labels)
print(f"Adjusted Rand Index: {a_ri}")
print(f"Normalized Mutual Information Score: {n_mi}")
# Out:
# Adjusted Rand Index: 0.10195062061154142
# Normalized Mutual Information Score: 0.05363299756244609
